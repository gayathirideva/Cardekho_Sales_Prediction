# %%
import pandas as pd 
import numpy as np
import json
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt

import warnings

#warnings.filterwarnings("ignore", category=FutureWarning)
#pd.set_option('display.max_column', 50)

# %%
excel_file1 = 'C:/Users/LENOVO/Downloads/Cardekho/chennai_cars.xlsx'

df = pd.read_excel(excel_file1,sheet_name = 'chennai_cars.csv')

# %%
df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Minivans', 'k...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1414  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1415  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1416  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1417  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1418  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
excel_file2 = 'C:/Users/LENOVO/Downloads/Cardekho/bangalore_cars.xlsx'

df2 = pd.read_excel(excel_file2,sheet_name = 'bangalore_cars.csv')
df2
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1476  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1477  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1478  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
excel_file3 = 'C:/Users/LENOVO/Downloads/Cardekho/delhi_cars.xlsx'

df3 = pd.read_excel(excel_file3,sheet_name = 'delhi_cars.csv')
df3
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1480  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1483  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1484  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
excel_file4 = 'C:/Users/LENOVO/Downloads/Cardekho/hyderabad_cars.xlsx'

df4 = pd.read_excel(excel_file4,sheet_name = 'hyderabad_cars.csv')
df4
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1478  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1479  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1480  {'it': 0, 'ft': 'Diesel', 'bt': 'Sedan', 'km':...
# 1481  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# 1482  {'it': 0, 'ft': 'Diesel', 'bt': 'MUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
excel_file5 = 'C:/Users/LENOVO/Downloads/Cardekho/jaipur_cars.xlsx'

df5 = pd.read_excel(excel_file5,sheet_name = 'jaipur_cars.csv')
df5
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Diesel', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# ...                                                 ...
# 1115  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1116  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1117  {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 1118  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1119  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
excel_file6 = 'C:/Users/LENOVO/Downloads/Cardekho/kolkata_cars.xlsx'

df6 = pd.read_excel(excel_file6,sheet_name = 'kolkata_cars.csv')
df6
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 1376  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1377  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1378  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 1379  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1380  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
import pandas as pd
import glob

# Specify the path to the directory containing your CSV files
csv_files_path = 'C:/Users/LENOVO/Downloads/Cardekho/'

# Use glob to get a list of all CSV files in the specified directory
csv_files = glob.glob(csv_files_path + '*.xlsx')

# Initialize an empty list to store DataFrames
dfs = []

# Iterate through each CSV file and read it into a DataFrame
for csv_file in csv_files:
    df = pd.read_excel(csv_file)
    dfs.append(df)

# Concatenate the DataFrames vertically
result_df = pd.concat(dfs, ignore_index=True)

# Now 'result_df' contains the concatenated data from all CSV files
print(result_df)
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 8364  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8365  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8366  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 8367  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8368  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
result_df
# Out:
#                                          new_car_detail  \
# 0     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 1     {'it': 0, 'ft': 'Petrol', 'bt': 'SUV', 'km': '...
# 2     {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 3     {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 4     {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
# ...                                                 ...
# 8364  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8365  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8366  {'it': 0, 'ft': 'Petrol', 'bt': 'Sedan', 'km':...
# 8367  {'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', '...
# 8368  {'it': 0, 'ft': 'Diesel', 'bt': 'SUV', 'km': '...
#
#                                        new_car_overview  \
# 0     {'heading': 'Car overview', 'top': [{'key': 'R...
# 1     {'heading': 'Car overview', 'top': [{'key': 'R...
# 2     {'heading': 'Car overview', 'top': [{'key': 'R...
# 3     {'heading': 'Car overview', 'top': [{'key': 'R...
# ...

# %%
#new_car_detail 
result_df['new_car_detail'][0]
# Out:
# "{'it': 0, 'ft': 'Petrol', 'bt': 'Hatchback', 'km': '1,20,000', 'transmission': 'Manual', 'ownerNo': 3, 'owner': '3rd Owner', 'oem': 'Maruti', 'model': 'Maruti Celerio', 'modelYear': 2015, 'centralVariantId': 3979, 'variantName': 'VXI', 'price': '₹ 4 Lakh', 'priceActual': '', 'priceSaving': '', 'priceFixedText': None, 'trendingText': {'imgUrl': 'https://stimg.cardekho.com/used-cars/common/icons/trending.svg', 'heading': 'Trending Car!', 'desc': 'High chances of sale in next 6 days'}}"

# %%
'''# Assuming result_df['new_car_detail'][0] is a string containing JSON data
json_data = result_df['new_car_detail']

# Convert the JSON string to a Python dictionary
data_dict = eval(json_data)

# Use json_normalize to flatten the nested structure
flat_data = json_normalize(data_dict)

# Now 'flat_data' contains the cleaned data in a DataFrame
print(flat_data)

# Each column is values are put in json format, clean the data to the required form.

df1 = pd.DataFrame(df.new_car_detail.apply(eval).tolist())
df1

import ast 

result_df['new_car_detail'] = result_df['new_car_detail'].apply(ast.literal_eval)
new_car_list = result_df['new_car_detail'].tolist()
new_car_list
'''
# Out:
# "# Assuming result_df['new_car_detail'][0] is a string containing JSON data\njson_data = result_df['new_car_detail']\n\n# Convert the JSON string to a Python dictionary\ndata_dict = eval(json_data)\n\n# Use json_normalize to flatten the nested structure\nflat_data = json_normalize(data_dict)\n\n# Now 'flat_data' contains the cleaned data in a DataFrame\nprint(flat_data)\n\n# Each column is values are put in json format, clean the data to the required form.\n\ndf1 = pd.DataFrame(df.new_car_detail.apply(eval).tolist())\ndf1\n\nimport ast \n\nresult_df['new_car_detail'] = result_df['new_car_detail'].apply(ast.literal_eval)\nnew_car_list = result_df['new_car_detail'].tolist()\nnew_car_list\n"

# %%
# Assuming 'df' is your DataFrame
# If 'df' is not already created, you need to load your data into a DataFrame first

df1 = pd.DataFrame(result_df.new_car_detail.apply(eval).tolist())
# Evaluate the 'new_car_detail' column and convert it into a DataFrame
df1 = pd.DataFrame(result_df.new_car_detail.apply(eval).tolist())

# Check if 'trendingText' exists before extracting 'desc'
df1['Description'] = df1.apply(lambda x: x['trendingText'].get('desc', '') if 'trendingText' in x else '', axis=1)

# Drop the 'trendingText' column
df1.drop('trendingText', axis=1, inplace=True)

# Display the modified DataFrame
df1
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  centralVariantId  \
# ...

# %%
result_df['new_car_overview'][0]
# Out:
# "{'heading': 'Car overview', 'top': [{'key': 'Registration Year', 'value': '2015', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/registrationYear.svg'}, {'key': 'Insurance Validity', 'value': 'Third Party insurance', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/insuranceValidity.svg'}, {'key': 'Fuel Type', 'value': 'Petrol', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/fuel.svg'}, {'key': 'Seats', 'value': '5 Seats', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/seats.svg'}, {'key': 'Kms Driven', 'value': '1,20,000 Kms', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/kmsDriven.svg'}, {'key': 'RTO', 'value': 'KA51', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/rto.svg'}, {'key': 'Ownership', 'value': 'Third Owner', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/ownership.svg'}, {'key': 'Engine Displacement', 'value': '998 cc', 'icon': 'https://images10.gaadi.com/listing/vdp/co/v1/engineDisplacement.svg'}, {'key': 'Transmission',
# ...

# %%
def df_overview(data):
    return {value['key'] : value['value'] for value in data}

result_df.new_car_overview =result_df.new_car_overview.apply(lambda x: df_overview(eval(x).get('top')))
df2_overview = pd.DataFrame(result_df.new_car_overview.tolist())
df2_overview.drop('Seats', axis = 1, inplace = True)
df2_overview
# Out:
#      Registration Year     Insurance Validity Fuel Type    Kms Driven   RTO  \
# 0                 2015  Third Party insurance    Petrol  1,20,000 Kms  KA51
# 1             Feb 2018          Comprehensive    Petrol    32,706 Kms  KA05
# 2            Sept 2018          Comprehensive    Petrol    11,949 Kms  KA03
# 3             Dec 2014          Comprehensive    Petrol    17,794 Kms  KA53
# 4                 2015  Third Party insurance    Diesel    60,000 Kms  KA04
# ...                ...                    ...       ...           ...   ...
# 8364              2022  Third Party insurance    Petrol    10,000 Kms   NaN
# 8365              2014  Third Party insurance    Petrol  1,20,000 Kms   NaN
# 8366              2011  Third Party insurance    Petrol    50,000 Kms  WB06
# 8367              2012  Third Party insurance    Petrol    40,000 Kms   NaN
# 8368              2017  Third Party insurance    Diesel  1,20,000 Kms   NaN
#
# ...

# %%
result_df['new_car_feature']
# Out:
# 0       {'heading': 'Features', 'top': [{'value': 'Pow...
# 1       {'heading': 'Features', 'top': [{'value': 'Pow...
# 2       {'heading': 'Features', 'top': [{'value': 'Pow...
# 3       {'heading': 'Features', 'top': [{'value': 'Pow...
# 4       {'heading': 'Features', 'top': [{'value': 'Pow...
#                               ...
# 8364    {'heading': 'Features', 'top': [{'value': 'Pow...
# 8365    {'heading': 'Features', 'top': [{'value': 'Pow...
# 8366    {'heading': 'Features', 'top': [{'value': 'Pow...
# 8367    {'heading': 'Features', 'top': [{'value': 'Pow...
# 8368    {'heading': 'Features', 'top': [{'value': 'Pow...
# Name: new_car_feature, Length: 8369, dtype: object

# %%
result_df['new_car_feature'][0]
# Out:
# "{'heading': 'Features', 'top': [{'value': 'Power Steering'}, {'value': 'Power Windows Front'}, {'value': 'Air Conditioner'}, {'value': 'Heater'}, {'value': 'Adjustable Head Lights'}, {'value': 'Manually Adjustable Exterior Rear View Mirror'}, {'value': 'Centeral Locking'}, {'value': 'Child Safety Locks'}], 'data': [{'heading': 'Comfort & Convenience', 'subHeading': 'Comfort', 'list': [{'value': 'Power Steering'}, {'value': 'Power Windows Front'}, {'value': 'Power Windows Rear'}, {'value': 'Remote Trunk Opener'}, {'value': 'Remote Fuel Lid Opener'}, {'value': 'Low Fuel Warning Light'}, {'value': 'Accessory Power Outlet'}, {'value': 'Vanity Mirror'}, {'value': 'Rear Seat Headrest'}, {'value': 'Cup Holders Front'}]}, {'heading': 'Interior', 'subHeading': 'Interior', 'list': [{'value': 'Air Conditioner'}, {'value': 'Heater'}, {'value': 'Digital Odometer'}, {'value': 'Electronic Multi Tripmeter'}, {'value': 'Fabric Upholstery'}, {'value': 'Glove Compartment'}, {'value': 'Digital Clock'}]
# ...

# %%
result_df['new_car_feature'][0]['heading']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 result_df['new_car_feature'][0]['heading']
#
# TypeError: string indices must be integers, not 'str'

# %%
# Each column is values are put in json format, clean the data to the required form.

df3_feature = pd.DataFrame(result_df.new_car_feature.apply(eval).tolist())
df3_feature
# Out:
#        heading                                                top  \
# 0     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 1     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 2     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 3     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 4     Features  [{'value': 'Power Steering'}, {'value': 'Power...
# ...        ...                                                ...
# 8364  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 8365  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 8366  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 8367  Features  [{'value': 'Power Steering'}, {'value': 'Power...
# 8368  Features  [{'value': 'Power Steering'}, {'value': 'Power...
#
#                                                    data  \
# 0     [{'heading': 'Comfort & Convenience', 'subHead...
# 1     [{'heading': 'Comfort & Convenience', 'subHead...
# ...

# %%
features=[]

for item_list in df3_feature['top']:
    if item_list:
        features.append([item['value'] for item in item_list])
    else:
        features.append('Not Value')
features
# Out:
# [['Power Steering',
#   'Power Windows Front',
#   'Air Conditioner',
#   'Heater',
#   'Adjustable Head Lights',
#   'Manually Adjustable Exterior Rear View Mirror',
#   'Centeral Locking',
#   'Child Safety Locks'],
#  ['Power Steering',
#   'Power Windows Front',
#   'Air Conditioner',
#   'Heater',
#   'Adjustable Head Lights',
#   'Fog Lights Front',
#   'Anti Lock Braking System',
#   'Centeral Locking',
#   'Cd Player'],
#  ['Power Steering',
#   'Power Windows Front',
#   'Air Conditioner',
#   'Heater',
#   'Adjustable Head Lights',
#   'Fog Lights Front',
#   'Anti Lock Braking System',
#   'Centeral Locking',
#   'Cd Player'],
#  ['Power Steering',
#   'Power Windows Front',
#   'Air Conditioner',
#   'Heater',
#   'Adjustable Head Lights',
#   'Fog Lights Front',
#   'Anti Lock Braking System',
#   'Centeral Locking',
#   'Cd Player'],
#  ['Power Steering',
#   'Power Windows Front',
#   'Air Conditioner',
#   'Heater',
#   'Adjustable Head Lights',
# ...

# %%
# Assuming df3['data'] is a list of dictionaries

Comfort = []
Interior = []
Exterior = []
Safety = []

for i in range(len(df3_feature['data'])):
    col = [Comfort, Interior, Exterior, Safety]
    
    #for j in range(0, 4):
    try:
            # Check if subHeading matches the column, then extend the list
        if df3_feature['data'][i][0]['subHeading'] == 'Comfort':
            values = [item['value'] for item in df3_feature['data'][i][0]['list']]
            Comfort.append(values)
        else: # If subHeading doesn't match, extend with 'No value'
                Comfort.append(['No value'])
    except IndexError:
            # If index doesn't exist, extend with 'No value'
            Comfort.append(['No value'])
    try:
            # Check if subHeading matches the column, then extend the list
        if df3_feature['data'][i][1]['subHeading'] == 'Interior':
            values = [item['value'] for item in df3_feature['data'][i][1]['list']]
            #Interior.append(df3['data'][i][1]['list'])
            Interior.append(values)
        else:
            #If subHeading doesn't match, extend with 'No value'
            Interior.append(['No value'])
    except IndexError:
        # If index doesn't exist, extend with 'No value'
        Interior.append(['No value'])
    try:
        # Check if subHeading matches the column, then extend the list
        if df3_feature['data'][i][2]['subHeading'] == 'Exterior':
            values = [item['value'] for item in df3_feature['data'][i][2]['list']]
            #Exterior.append(df3['data'][i][2]['list'])
            Exterior.append(values)
        else:
          # If subHeading doesn't match, extend with 'No value'
           Exterior.append(['No value'])
    except IndexError:
            # If index doesn't exist, extend with 'No value' 
            Exterior.append(['No value'])
        
    try:
            # Check if subHeading matches the column, then extend the list
        if df3_feature['data'][i][3]['subHeading'] == 'Safety':
            values = [item['value'] for item in df3_feature['data'][i][3]['list']]
            #Safety.append(df3['data'][i][3]['list'])
            Safety.append(values)
        else:
          # If subHeading doesn't match, extend with 'No value'
            Safety.append(['No value'])
    except IndexError:
            # If index doesn't exist, extend with 'No value'
            Safety.append(['No value'])
            
        

# Now, col will contain the extended lists for Comfort, Interior, Exterior, and Safety

# %%
pop = {'Features' : features,'Comfort':Comfort,'Interior': Interior,'Exterior': Exterior,'Safety' :Safety}

poup = pd.DataFrame(pop)

poup
# Out:
#                                                Features  \
# 0     [Power Steering, Power Windows Front, Air Cond...
# 1     [Power Steering, Power Windows Front, Air Cond...
# 2     [Power Steering, Power Windows Front, Air Cond...
# 3     [Power Steering, Power Windows Front, Air Cond...
# 4     [Power Steering, Power Windows Front, Air Cond...
# ...                                                 ...
# 8364  [Power Steering, Power Windows Front, Air Cond...
# 8365  [Power Steering, Power Windows Front, Air Cond...
# 8366  [Power Steering, Power Windows Front, Air Cond...
# 8367  [Power Steering, Power Windows Front, Air Cond...
# 8368  [Power Steering, Power Windows Front, Air Cond...
#
#                                                 Comfort  \
# 0     [Power Steering, Power Windows Front, Power Wi...
# 1     [Power Steering, Power Windows Front, Power Wi...
# 2     [Power Steering, Power Windows Front, Power Wi...
# 3     [Power Steering, Power Windows Front, Power Wi...
# ...

# %%
def specification(data):
    extract = {}
    for value in data['top']:
        extract[value['key']] = value['value']

    try:
        for i in range(3):
            for value in data['data'][i]['list']:
                extract[value['key']] = value['value']
    except:
        pass

    return extract

result_df.new_car_specs = result_df.new_car_specs.apply(lambda x: specification(eval(x)))
speci_df=pd.DataFrame(result_df.new_car_specs.tolist())
speci_df
# Out:
#          Mileage   Engine          Max Power    Torque Seats   Color  \
# 0      23.1 kmpl   998 CC   67.04bhp@6000rpm      90Nm     5   White
# 1        17 kmpl  1497 CC  121.31bhp@6500rpm     150Nm     5   White
# 2     23.84 kmpl  1199 CC      84bhp@6000rpm     114Nm     5     Red
# 3      19.1 kmpl  1197 CC   81.86bhp@6000rpm  113.75Nm     5  Others
# 4     23.65 kmpl  1248 CC    88.5bhp@4000rpm     200Nm     5    Gray
# ...          ...      ...                ...       ...   ...     ...
# 8364  25.24 kmpl   998 CC   65.71bhp@5500rpm      89Nm     5  Others
# 8365  22.74 kmpl   796 CC    47.3bhp@6000rpm      69Nm     5  Others
# 8366  11.74 kmpl  1796 CC     186bhp@5600rpm     285Nm     5  Others
# 8367   18.5 kmpl  1197 CC   85.80bhp@6000rpm     114Nm     5  Others
# 8368  19.72 kmpl  1461 CC  108.45bhp@4000rpm     245Nm     5  Others
#
#                    Engine Type Displacement          Max Torque  \
# 0                  K10B Engine          998        90Nm@3500rpm
# ...

# %%
final_df =pd.concat([df1, df2_overview, poup, speci_df], axis=1)
final_df
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Front Brake Type  \
# ...

# %%
final_cp = final_df.copy()

# %%
final_cp
# Out:
#       it      ft         bt        km transmission  ownerNo      owner  \
# 0      0  Petrol  Hatchback  1,20,000       Manual        3  3rd Owner
# 1      0  Petrol        SUV    32,706       Manual        2  2nd Owner
# 2      0  Petrol  Hatchback    11,949       Manual        1  1st Owner
# 3      0  Petrol      Sedan    17,794       Manual        1  1st Owner
# 4      0  Diesel        SUV    60,000       Manual        1  1st Owner
# ...   ..     ...        ...       ...          ...      ...        ...
# 8364   0  Petrol  Hatchback    10,000       Manual        1  1st Owner
# 8365   0  Petrol  Hatchback  1,20,000       Manual        1  1st Owner
# 8366   0  Petrol      Sedan    50,000    Automatic        3  3rd Owner
# 8367   0  Petrol  Hatchback    40,000       Manual        1  1st Owner
# 8368   0  Diesel        SUV  1,20,000       Manual        2  2nd Owner
#
#                 oem                  model  modelYear  ...  Front Brake Type  \
# ...

# %%
# Removing the columns which will not make any impact are removed, since they have either one value or 'this or that values'.

#it values are '0'
#ft values are either petrol or diesel
# Tramission also have only 2 values 
# Owner no and ower both are same , removing the owner col.
# priceFixedText(None value), Ownership (already exist), Description (same text is repeated), priceSaving (blank).'Ground Clearance Unladen'(NaN)
#Wheel Size (same as Alloy wheel size), Engine(Displacement, same valaues),
#Super Charger,Turbo Charger, Drive Type,Seating Capacity(all value is 5),
#Cargo Volumn (values are not there),'Ground Clearance Unladen' (Nan value),Engine, 
#Seating Capacity same value, Drive Type,BoreX Stroke,'Compression Ratio'
# priceSaving is blank

# %%
drop_col =['it', 'ft', 'km','transmission', 'owner', 'priceSaving', 'Description', 'priceFixedText', 'Ownership',
                    'Features', 'Comfort', 'Interior', 'Exterior', 'Engine','Displacement','Turbo Charger', 'Super Charger',
                    'Kerb Weight', 'Gross Weight','Drive Type', 'Seating Capacity', 'Turning Radius', 'Acceleration', 
                    'Cargo Volumn', 'Wheel Size', 'Alloy Wheel Size', 'Ground Clearance Unladen', 'Values per Cylinder', 'Value Configuration',
                    'Fuel Suppy System', 'BoreX Stroke', 'Compression Ratio', 'Length','Width', 'Height', 'Wheel Base', 'Front Tread', 'Rear Tread',]

alter_df = final_cp.drop(columns = drop_col)
alter_df

#[ 'km','Features', 'Comfort', 'Interior', 'Exterior', 'Engine','Displacement',
 #                   'Kerb Weight', 'Gross Weight','Turning Radius', 'Acceleration', 
  #                  'Length','Width', 'Height', 'Wheel Base', 'Front Tread', 'Rear Tread',]
# Out:
#              bt  ownerNo            oem                  model  modelYear  \
# 0     Hatchback        3         Maruti         Maruti Celerio       2015
# 1           SUV        2           Ford          Ford Ecosport       2018
# 2     Hatchback        1           Tata             Tata Tiago       2018
# 3         Sedan        1        Hyundai          Hyundai Xcent       2014
# 4           SUV        1         Maruti     Maruti SX4 S Cross       2015
# ...         ...      ...            ...                    ...        ...
# 8364  Hatchback        1         Maruti         Maruti Celerio       2022
# 8365  Hatchback        1         Maruti        Maruti Alto 800       2014
# 8366      Sedan        3  Mercedes-Benz  Mercedes-Benz C-Class       2011
# 8367  Hatchback        1         Maruti            Maruti Ritz       2012
# 8368        SUV        2        Renault         Renault Duster       2017
#
#       centralVariantId               variantName        price priceActual  \
# ...

# %%
alter_df.columns
# Out:
# Index(['bt', 'ownerNo', 'oem', 'model', 'modelYear', 'centralVariantId',
#        'variantName', 'price', 'priceActual', 'Registration Year',
#        'Insurance Validity', 'Fuel Type', 'Kms Driven', 'RTO',
#        'Engine Displacement', 'Transmission', 'Year of Manufacture', 'Safety',
#        'Mileage', 'Max Power', 'Torque', 'Seats', 'Color', 'Engine Type',
#        'Max Torque', 'No of Cylinder', 'Gear Box', 'Steering Type',
#        'Front Brake Type', 'Rear Brake Type', 'Top Speed', 'Tyre Type',
#        'No Door Numbers'],
#       dtype='object')

# %%
#alter_df[''].isnull().sum() 
#'Ground Clearance Unladen', Wheel Size (same as Alloy wheel size), Engine(Displacement, same valaues),
#Super Charger,Turbo Charger, Drive Type,Seating Capacity(all value is 5),
#Cargo Volumn (values are not there),'Ground Clearance Unladen' (Nan value),Engine, 
#Seating Capacity same value, Drive Type,BoreX Stroke,'Compression Ratio'
# priceSaving is blank

# %%
alter_df.isnull().sum()
# Out:
# bt                        0
# ownerNo                   0
# oem                       0
# model                     0
# modelYear                 0
# centralVariantId          0
# variantName               0
# price                     0
# priceActual               0
# Registration Year        52
# Insurance Validity        4
# Fuel Type                 0
# Kms Driven                2
# RTO                     888
# Engine Displacement       4
# Transmission              0
# Year of Manufacture      20
# Safety                    0
# Mileage                 287
# Max Power                60
# Torque                   60
# Seats                     5
# Color                     3
# Engine Type             295
# Max Torque               60
# No of Cylinder           31
# Gear Box                106
# Steering Type           255
# Front Brake Type         96
# Rear Brake Type          96
# Top Speed              3762
# Tyre Type                77
# No Door Numbers          11
# ...

# %%
#categorical_columns

# %%
#numerical_columns

# %%
alter_df
# Out:
#              bt  ownerNo            oem                  model  modelYear  \
# 0     Hatchback        3         Maruti         Maruti Celerio       2015
# 1           SUV        2           Ford          Ford Ecosport       2018
# 2     Hatchback        1           Tata             Tata Tiago       2018
# 3         Sedan        1        Hyundai          Hyundai Xcent       2014
# 4           SUV        1         Maruti     Maruti SX4 S Cross       2015
# ...         ...      ...            ...                    ...        ...
# 8364  Hatchback        1         Maruti         Maruti Celerio       2022
# 8365  Hatchback        1         Maruti        Maruti Alto 800       2014
# 8366      Sedan        3  Mercedes-Benz  Mercedes-Benz C-Class       2011
# 8367  Hatchback        1         Maruti            Maruti Ritz       2012
# 8368        SUV        2        Renault         Renault Duster       2017
#
#       centralVariantId               variantName        price priceActual  \
# ...

# %%
alter_df.isnull().sum()
# Out:
# bt                        0
# ownerNo                   0
# oem                       0
# model                     0
# modelYear                 0
# centralVariantId          0
# variantName               0
# price                     0
# priceActual               0
# Registration Year        52
# Insurance Validity        4
# Fuel Type                 0
# Kms Driven                2
# RTO                     888
# Engine Displacement       4
# Transmission              0
# Year of Manufacture      20
# Safety                    0
# Mileage                 287
# Max Power                60
# Torque                   60
# Seats                     5
# Color                     3
# Engine Type             295
# Max Torque               60
# No of Cylinder           31
# Gear Box                106
# Steering Type           255
# Front Brake Type         96
# Rear Brake Type          96
# Top Speed              3762
# Tyre Type                77
# No Door Numbers          11
# ...

# %%
# MISSING VALUES 

alter_df['Registration Year'].fillna(alter_df['modelYear'], inplace=True)
alter_df['Year of Manufacture'].fillna(alter_df['modelYear'], inplace=True)

# %%
# Create a mapping dictionary for model and its corresponding Seats value
model_to_seat_mapping = alter_df.groupby('model')['Seats'].unique().apply(lambda x: x[0]).to_dict()

# Fill missing 'Seats' values using the mapping
alter_df['Seats'].fillna(final_df['model'].map(model_to_seat_mapping), inplace=True)

# %%
car_model = alter_df[alter_df.Seats.isna()==True]['oem']
car_variant = alter_df[alter_df.Seats.isna()==True]['variantName']
car_seat = [alter_df[(alter_df['oem']==model) & (alter_df['variantName']==var)].Seats.unique()[0] for model, var in zip(car_model, car_variant)]
car_seat_index = alter_df[alter_df.Seats.isna()==True].index
alter_df.loc[car_seat_index, 'Seats'] = car_seat

# %%
#df['B'] = df.groupby('A')['B'].transform(lambda x: x.fillna(method='ffill').fillna(method='bfill'))
#Ins_vali = alter_df.groupby('model')['Insurance Validity']

#Ins_vali
Ins_val = alter_df.groupby('model')['Insurance Validity'].apply(lambda x : x.to_dict())
alter_df['Insurance Validity'].fillna(alter_df['model'].map(Ins_val), inplace =True)

# %%
car_model = alter_df[final_df['Mileage'].isna()==True]['oem']
car_variant = alter_df[alter_df['Mileage'].isna()==True]['variantName']
car_mileage = [alter_df[(alter_df['oem']==model) & (alter_df['variantName']==var) ]['Mileage'].unique()[0] for model, var in zip(car_model, car_variant)]
car_mileage_index =alter_df[alter_df['Mileage'].isna()==True].index

alter_df.loc[car_mileage_index, 'Mileage'] = car_mileage

# %%
car_model = alter_df[alter_df['Mileage'].isna()==True]['oem']
car_mileage = [alter_df[(alter_df['oem']==model) & (alter_df['Mileage'].isna()==False) ]['Mileage'].value_counts().index[0] for model in car_model]

car_mileage_index =alter_df[alter_df['Mileage'].isna()==True].index
alter_df.loc[car_mileage_index, 'Mileage'] = car_mileage

# %%
car_model = alter_df[alter_df['Engine Type'].isna()==True]['model']
car_displacement = alter_df[alter_df['Engine Type'].isna()==True]['Engine Displacement']
car_engine = [alter_df[(alter_df['model']==model) & (alter_df['Engine Displacement']==dis)]['Engine Type'].value_counts() for model, dis in zip(car_model, car_displacement)]
car_engine = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_engine]

car_engine_index =alter_df[alter_df['Engine Type'].isna()==True].index

final_df.loc[car_engine_index, 'Engine Type'] = car_engine

# %%
car_model = alter_df[alter_df['Top Speed'].isna()==True]['model']
car_variant = alter_df[alter_df['Top Speed'].isna()==True]['variantName']
car_top_speed = [alter_df[(alter_df['model']==model) & (alter_df['variantName']==var) & (alter_df['Top Speed'].isna()==False)]['Top Speed'].value_counts() for model, var in zip(car_model, car_variant)]
car_top_speed = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_top_speed]
car_top_speed_index = alter_df[alter_df['Top Speed'].isna()==True].index


alter_df.loc[car_top_speed_index, 'Top Speed'] = car_top_speed

# %%
car_model = alter_df[alter_df['Top Speed'].isna()==True]['model']
car_engine_type = alter_df[alter_df['Top Speed'].isna()==True]['Engine Type']
car_top_speed = [alter_df[(alter_df['model']==model) & (alter_df['Engine Type']==engine) & (alter_df['Top Speed'].isna()==False)]['Top Speed'].value_counts() for model, engine in zip(car_model, car_engine_type)]
car_top_speed = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_top_speed]
car_top_speed_index = alter_df[alter_df['Top Speed'].isna()==True].index


alter_df.loc[car_top_speed_index, 'Top Speed'] = car_top_speed

# %%
car_model = alter_df[alter_df['Top Speed'].isna()==True]['oem']
car_variant = alter_df[alter_df['Top Speed'].isna()==True]['variantName']
car_top_speed = [alter_df[(alter_df['oem']==model) & (alter_df['variantName']==var) & (alter_df['Top Speed'].isna()==False)]['Top Speed'].value_counts() for model, var in zip(car_model, car_variant)]
car_top_speed = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_top_speed]
car_top_speed_index = alter_df[alter_df['Top Speed'].isna()==True].index


alter_df.loc[car_top_speed_index, 'Top Speed'] = car_top_speed

# %%
car_model = alter_df[alter_df['Top Speed'].isna()==True]['model']
car_max_power = alter_df[alter_df['Top Speed'].isna()==True]['Max Power']
car_top_speed = [alter_df[(alter_df['model']==model) & (alter_df['Max Power']== power) & (alter_df['Top Speed'].isna()==False)]['Top Speed'].value_counts() for model, power in zip(car_model, car_max_power)]
car_top_speed = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_top_speed]
car_top_speed_index = alter_df[alter_df['Top Speed'].isna()==True].index


alter_df.loc[car_top_speed_index, 'Top Speed'] = car_top_speed

# %%
car_model = alter_df[alter_df['Top Speed'].isna()==True]['model']
car_displacement = alter_df[alter_df['Top Speed'].isna()==True]['Engine Displacement']
car_top_speed = [alter_df[(final_df['model']==model) & (alter_df['Engine Displacement']== dis) & (alter_df['Top Speed'].isna()==False)]['Top Speed'].value_counts() for model, dis in zip(car_model, car_displacement)]
car_top_speed = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_top_speed]
car_top_speed_index = alter_df[alter_df['Top Speed'].isna()==True].index


alter_df.loc[car_top_speed_index, 'Top Speed'] = car_top_speed

# %%
car_model = alter_df[alter_df['Gear Box'].isna()==True]['oem']
car_engine = alter_df[alter_df['Gear Box'].isna()==True]['Engine Type']
car_gear = [alter_df[(alter_df['oem']==model) & (alter_df['Engine Type']== engine)& (alter_df['Gear Box'].isna()==False)]['Gear Box'].value_counts() for model, engine in zip(car_model, car_engine)]
car_gear = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_gear]
car_gear_index = alter_df[alter_df['Gear Box'].isna()==True].index


alter_df.loc[car_gear_index, 'Gear Box'] = car_gear

# %%
car_model = alter_df[alter_df['Steering Type'].isna()==True]['oem']
car_variant = alter_df[alter_df['Steering Type'].isna()==True]['variantName']
car_Steering = [alter_df[(alter_df['oem']==model) & (alter_df['variantName']== var)& (alter_df['Steering Type'].isna()==False)]['Steering Type'].value_counts() for model, var in zip(car_model, car_variant)]
car_Steering = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_Steering]
car_Steering_index = alter_df[alter_df['Steering Type'].isna()==True].index

alter_df.loc[car_Steering_index, 'Steering Type'] = car_Steering

# %%
car_model = alter_df[alter_df['Steering Type'].isna()==True]['model']
car_Steering = [alter_df[(alter_df['model']==model)& (alter_df['Steering Type'].isna()==False)]['Steering Type'].value_counts() for model in car_model]
car_Steering = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_Steering]
car_Steering_index = alter_df[alter_df['Steering Type'].isna()==True].index

alter_df.loc[car_Steering_index, 'Steering Type'] = car_Steering

# %%
car_model = alter_df[alter_df['Tyre Type'].isna()==True]['model']
car_tyre = [alter_df[(alter_df['model']==model)&  (alter_df['Tyre Type'].isna()==False)]['Tyre Type'].value_counts() for model, var in zip(car_model, car_variant)]
car_tyre = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_tyre]
car_tyre_index = alter_df[alter_df['Tyre Type'].isna()==True].index

alter_df.loc[car_tyre_index, 'Tyre Type'] = car_tyre

# %%
car_model = alter_df[alter_df['Front Brake Type'].isna()==True]['model']
car_break = [alter_df[(alter_df['model']==model) & (alter_df['Front Brake Type'].isna()==False)]['Front Brake Type'].value_counts() for model in car_model]
car_break = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_break]
car_break_index = alter_df[alter_df['Front Brake Type'].isna()==True].index

alter_df.loc[car_break_index, 'Front Brake Type'] = car_break

# %%
car_model = alter_df[alter_df['Rear Brake Type'].isna()==True]['model']
car_break = [alter_df[(alter_df['model']==model) & (alter_df['Rear Brake Type'].isna()==False)]['Rear Brake Type'].value_counts() for model in car_model]
car_break = [value.index[0] if value.shape[0]!=0 else np.nan for value in car_break]
car_break_index = alter_df[alter_df['Rear Brake Type'].isna()==True].index

alter_df.loc[car_break_index, 'Rear Brake Type'] = car_break

# %%
categorical_columns = alter_df.select_dtypes(include='object').columns
numerical_columns = alter_df.select_dtypes(exclude='object').columns

# %%
numerical_columns
# Out:
# Index(['ownerNo', 'modelYear', 'centralVariantId', 'Year of Manufacture',
#        'No of Cylinder'],
#       dtype='object')

# %%
alter_df['ownerNo'].fillna(alter_df['ownerNo'].mode()[0], inplace=True)
alter_df['modelYear'].fillna(alter_df['modelYear'].mode()[0], inplace=True)
alter_df['centralVariantId'].fillna(alter_df['centralVariantId'].mode()[0], inplace=True)
alter_df['Year of Manufacture'].fillna(alter_df['Year of Manufacture'].mode()[0], inplace=True)
alter_df['No of Cylinder'].fillna(alter_df['No of Cylinder'].mode()[0], inplace=True)

# %%
categorical_columns
# Out:
# Index(['bt', 'oem', 'model', 'variantName', 'price', 'priceActual',
#        'Registration Year', 'Insurance Validity', 'Fuel Type', 'Kms Driven',
#        'RTO', 'Engine Displacement', 'Transmission', 'Safety', 'Mileage',
#        'Max Power', 'Torque', 'Seats', 'Color', 'Engine Type', 'Max Torque',
#        'Gear Box', 'Steering Type', 'Front Brake Type', 'Rear Brake Type',
#        'Top Speed', 'Tyre Type', 'No Door Numbers'],
#       dtype='object')

# %%
alter_df['No Door Numbers'].fillna(alter_df['No Door Numbers'].mode()[0], inplace=True)
#alter_df['Insurance Validity'].fillna(alter_df['Insurance Validity'].mode[0],inplace = True)
alter_df['Insurance Validity'].fillna(value = 'unknown',inplace = True)
alter_df['bt'].fillna(alter_df['bt'].mode()[0],inplace = True)
#alter_df['Kms Driven'].fillna(alter_df['Kms Driven'].mode[0],inplace = True)
alter_df['Kms Driven'].fillna(value = 0 ,inplace = True)
alter_df['priceActual'].fillna(alter_df['priceActual'].mode()[0] ,inplace = True)
alter_df['Seats'].fillna(alter_df['Seats'].mode()[0] ,inplace = True)
alter_df['Max Power'].fillna(alter_df['Max Power'].mode()[0], inplace=True)
alter_df['Torque'].fillna(alter_df['Torque'].mode()[0], inplace=True)
alter_df['Color'].fillna(alter_df['Color'].mode()[0], inplace=True)
alter_df['Engine Displacement'].fillna(alter_df['Engine Displacement'].mode()[0], inplace=True)
alter_df['Engine Type'].fillna(alter_df['Engine Type'].mode()[0], inplace=True)
alter_df['Max Torque'].fillna(alter_df['Max Torque'].mode()[0], inplace=True)
alter_df['Gear Box'].fillna(alter_df['Gear Box'].mode()[0], inplace=True)
alter_df['Steering Type'].fillna(alter_df['Steering Type'].mode()[0], inplace=True)
alter_df['Front Brake Type'].fillna(alter_df['Front Brake Type'].mode()[0], inplace=True)
alter_df['Rear Brake Type'].fillna(alter_df['Rear Brake Type'].mode()[0], inplace=True)
alter_df['Top Speed'].fillna(alter_df['Top Speed'].mode()[0], inplace=True)
alter_df['Tyre Type'].fillna(alter_df['Tyre Type'].mode()[0], inplace=True)

# %%
alter_df.isna().sum()
# Out:
# bt                     0
# ownerNo                0
# oem                    0
# model                  0
# modelYear              0
# centralVariantId       0
# variantName            0
# price                  0
# priceActual            0
# Registration Year      0
# Insurance Validity     0
# Fuel Type              0
# Kms Driven             0
# RTO                    0
# Engine Displacement    0
# Transmission           0
# Year of Manufacture    0
# Safety                 0
# Mileage                0
# Max Power              0
# Torque                 0
# Seats                  0
# Color                  0
# Engine Type            0
# Max Torque             0
# No of Cylinder         0
# Gear Box               0
# Steering Type          0
# Front Brake Type       0
# Rear Brake Type        0
# Top Speed              0
# Tyre Type              0
# No Door Numbers        0
# dtype: int64

# %%
#Ins_val = alter_df.groupby('model')['Insurance Validity'].apply(lambda x : x.to_dict())
#alter_df['Insurance Validity'].fillna(alter_df['model'].map(Ins_val), inplace =True)
alter_df['RTO'].fillna(value = '0',inplace = True)

# %%
alter_df.isnull().sum()
# Out:
# bt                     0
# ownerNo                0
# oem                    0
# model                  0
# modelYear              0
# centralVariantId       0
# variantName            0
# price                  0
# priceActual            0
# Registration Year      0
# Insurance Validity     0
# Fuel Type              0
# Kms Driven             0
# RTO                    0
# Engine Displacement    0
# Transmission           0
# Year of Manufacture    0
# Safety                 0
# Mileage                0
# Max Power              0
# Torque                 0
# Seats                  0
# Color                  0
# Engine Type            0
# Max Torque             0
# No of Cylinder         0
# Gear Box               0
# Steering Type          0
# Front Brake Type       0
# Rear Brake Type        0
# Top Speed              0
# Tyre Type              0
# No Door Numbers        0
# dtype: int64

# %%
# 'final_df' is the DataFrame
alter_df.to_csv('cardekho.csv', index=False)

# %%
fi_df = pd.read_csv('cardekho.csv') #data/mydata.csv'
fi_df
# Out:
#              bt  ownerNo            oem                  model  modelYear  \
# 0     Hatchback        3         Maruti         Maruti Celerio       2015
# 1           SUV        2           Ford          Ford Ecosport       2018
# 2     Hatchback        1           Tata             Tata Tiago       2018
# 3         Sedan        1        Hyundai          Hyundai Xcent       2014
# 4           SUV        1         Maruti     Maruti SX4 S Cross       2015
# ...         ...      ...            ...                    ...        ...
# 8364  Hatchback        1         Maruti         Maruti Celerio       2022
# 8365  Hatchback        1         Maruti        Maruti Alto 800       2014
# 8366      Sedan        3  Mercedes-Benz  Mercedes-Benz C-Class       2011
# 8367  Hatchback        1         Maruti            Maruti Ritz       2012
# 8368        SUV        2        Renault         Renault Duster       2017
#
#       centralVariantId               variantName        price priceActual  \
# ...

# %%
fi_df.isnull().sum()
# Out:
# bt                        4
# ownerNo                   0
# oem                       0
# model                     0
# modelYear                 0
# centralVariantId          0
# variantName               0
# price                     0
# priceActual            6699
# Registration Year         0
# Insurance Validity        0
# Fuel Type                 0
# Kms Driven                0
# RTO                       6
# Engine Displacement       0
# Transmission              0
# Year of Manufacture       0
# Safety                    0
# Mileage                   0
# Max Power                 0
# Torque                    0
# Seats                     1
# Color                     0
# Engine Type               0
# Max Torque                0
# No of Cylinder            0
# Gear Box                  0
# Steering Type             0
# Front Brake Type          0
# Rear Brake Type           0
# Top Speed                 0
# Tyre Type                 0
# No Door Numbers           0
# ...

# %%
fi_df['priceActual'].fillna(value = 0,inplace = True)
fi_df['bt'].fillna(fi_df['bt'].mode()[0],inplace = True)
fi_df['Seats'].fillna(fi_df['Seats'].mode()[0],inplace = True)
fi_df['RTO'].fillna(value = 'unknown',inplace =True)

# %%
fi_df.isnull().sum()
# Out:
# bt                     0
# ownerNo                0
# oem                    0
# model                  0
# modelYear              0
# centralVariantId       0
# variantName            0
# price                  0
# priceActual            0
# Registration Year      0
# Insurance Validity     0
# Fuel Type              0
# Kms Driven             0
# RTO                    0
# Engine Displacement    0
# Transmission           0
# Year of Manufacture    0
# Safety                 0
# Mileage                0
# Max Power              0
# Torque                 0
# Seats                  0
# Color                  0
# Engine Type            0
# Max Torque             0
# No of Cylinder         0
# Gear Box               0
# Steering Type          0
# Front Brake Type       0
# Rear Brake Type        0
# Top Speed              0
# Tyre Type              0
# No Door Numbers        0
# dtype: int64

# %%
fi_df.to_csv('fi_df.csv', index=False)

# %%
dr_df = pd.read_csv('fi_df.csv')

# %%
dr_df.isnull().sum()
# Out:
# bt                     0
# ownerNo                0
# oem                    0
# model                  0
# modelYear              0
# centralVariantId       0
# variantName            0
# price                  0
# priceActual            0
# Registration Year      0
# Insurance Validity     0
# Fuel Type              0
# Kms Driven             0
# RTO                    0
# Engine Displacement    0
# Transmission           0
# Year of Manufacture    0
# Safety                 0
# Mileage                0
# Max Power              0
# Torque                 0
# Seats                  0
# Color                  0
# Engine Type            0
# Max Torque             0
# No of Cylinder         0
# Gear Box               0
# Steering Type          0
# Front Brake Type       0
# Rear Brake Type        0
# Top Speed              0
# Tyre Type              0
# No Door Numbers        0
# dtype: int64
